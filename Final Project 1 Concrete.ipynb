# %%
import matplotlib.pyplot as plt          
import seaborn as sns
import numpy as np
import pandas as pd
print('lib import completed')
# Out:
# lib import completed

# %%
data= pd.read_csv('Concrete_Data - copy.csv')
X = data.iloc[:,[0,1,2,3,4,5,6]].values                  #independent values
y = data.iloc[:, 7].values                               #dependent values
data
# Out:
#       Cement  (component 1)(kg in a m^3 mixture)  \
# 0                                          540.0
# 1                                          540.0
# 2                                          332.5
# 3                                          332.5
# 4                                          198.6
# ...                                          ...
# 1025                                       276.4
# 1026                                       322.2
# 1027                                       148.5
# 1028                                       159.1
# 1029                                       260.9
#
#       Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# 0                                                   0.0
# 1                                                   0.0
# 2                                                 142.5
# 3                                                 142.5
# 4                                                 132.4
# ...

# %%
X=X.astype(np.float64)
Y=y.astype(np.float64)

# %%
#model evalution 
from sklearn.model_selection import train_test_split
Itrain,Itest,Dtrain,Dtest= train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression            #importing Linear Regression
LR=LinearRegression()
LR.fit(Itrain,Dtrain)
# Out:
# LinearRegression()

# %%
#prediction of test data
Yprediction=LR.predict(Itest)

# %%
import statsmodels.formula.api as sm                            #Importing ststsmodel
import statsmodels.regression.linear_model as SM

# %%
I=np.append(arr=np.ones([1030,5]).astype(int),values=X,axis=1)               #appending input values 
print(I)
# Out:
# [[1.000e+00 1.000e+00 1.000e+00 ... 2.500e+00 1.040e+03 6.760e+02]
#  [1.000e+00 1.000e+00 1.000e+00 ... 2.500e+00 1.055e+03 6.760e+02]
#  [1.000e+00 1.000e+00 1.000e+00 ... 0.000e+00 9.320e+02 5.940e+02]
#  ...
#  [1.000e+00 1.000e+00 1.000e+00 ... 6.100e+00 8.924e+02 7.800e+02]
#  [1.000e+00 1.000e+00 1.000e+00 ... 1.130e+01 9.896e+02 7.889e+02]
#  [1.000e+00 1.000e+00 1.000e+00 ... 8.600e+00 8.645e+02 7.615e+02]]

# %%
#endog-dependent
#exdog-independent
Iopt=I[:,[0,1,2,3,4,5,6]]
Optimizer=SM.OLS(endog=Y,exog=Iopt).fit()                              #OLS = ordinary least squares
Optimizer.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     3.737
# Date:                Sat, 18 Sep 2021   Prob (F-statistic):             0.0242
# Time:                        00:37:03   Log-Likelihood:                -5727.5
# No. Observations:                1030   AIC:                         1.146e+04
# Df Residuals:                    1027   BIC:                         1.148e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.8205      1.303      5.236      0.000       4.264       9.377
# ...

# %%
#endog-dependent
#exdog-independent
Iopt=I[:,[0,1,2,3]]                           #just taking most significant values.
Optimizer=SM.OLS(endog=Y,exog=Iopt).fit()
Optimizer.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Sat, 18 Sep 2021   Prob (F-statistic):                nan
# Time:                        00:37:07   Log-Likelihood:                -5731.2
# No. Observations:                1030   AIC:                         1.146e+04
# Df Residuals:                    1029   BIC:                         1.147e+04
# Df Model:                           0
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         11.4155      0.492     23.199      0.000      10.450      12.381
# ...
